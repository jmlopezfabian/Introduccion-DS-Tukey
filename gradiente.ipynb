# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

from utils import ecm, gradiente_descendente_m, calcular_y

# %%
df = pd.read_csv('data/csvs/examenes.csv')
df = df.sample(n = 100, replace = False)

# %%
x = np.array(df['study_hours'])
y = np.array(df['exam_score'])

# Normalizacion m = 0, std = 1
# Estandarizacion min-max

learning_rate = 0.01

m = 100

for i in range(0,1000):
    m = gradiente_descendente_m(m,learning_rate, 40, x, y)
    b = gradiente_descendente_m(b,learning_rate, m, x, y)
    print(i, m)
# Out:
# 0 64.26418676200001
# 1 42.06149312028242
# 2 28.26693913420514
# 3 19.696370051665653
# 4 14.371467595760318
# 5 11.063100800996073
# 6 9.007609467711598
# 7 7.730530811289926
# 8 6.937080667142777
# 9 6.444109362610021
# 10 6.13782583757022
# 11 5.947531601682148
# 12 5.829301617854192
# 13 5.755845220130298
# 14 5.710206692644556
# 15 5.68185143353022
# 16 5.664234284955644
# 17 5.653288734338484
# 18 5.646488253670135
# 19 5.642263108774449
# 20 5.639638022363625
# 21 5.638007053761501
# 22 5.63699373146851
# 23 5.636364153395618
# 24 5.635972995959719
# 25 5.635729969484929
# 26 5.635578976912559
# 27 5.635485165088431
# 28 5.635426879715794
# 29 5.635390666960152
# 30 5.635368167941756
# 31 5.635354189280927
# 32 5.635345504326095
# 33 5.635340108355667
# 34 5.635336755834276
# 35 5.635334672909651
# 36 5.635333378786665
# 37 5.635332574746863
# 38 5.635332075196195
# 39 5.6353317648249055
# 40 5.635331571990937
# 41 5.635331452183015
# 42 5.635331377746243
# ...

# %%
statsmodels

.fit
