# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from pathlib import Path
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../data/csvs/examenes.csv")
df.head()
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
#
#   internet_access  sleep_hours sleep_quality   study_method facility_rating  \
# 0             yes          7.4          poor       coaching             low
# 1             yes          4.6       average  online videos          medium
# 2             yes          8.5          poor       coaching            high
# 3             yes          5.8       average  online videos             low
# 4             yes          9.8          poor       coaching             low
#
#   exam_difficulty  exam_score
# 0            hard        58.9
# 1        moderate        54.8
# ...

# %% [markdown]
# # Min max scaler

# %%
from sklearn.preprocessing import MinMaxScaler

X = df[["class_attendance"]]
y = df[["exam_score"]]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Creando la instancia del escalador

scaler = MinMaxScaler()

# Hacer un fit al escalador, con los datos de entrenamiento

X_train_escalada = scaler.fit_transform(X_train)
y_train_escalada = scaler.fit_transform(y_train)


#Entrenamiento del modelo ....


# Validación del modeloaut

X_test_escalada = scaler.fit_transform(X_train)
y_test_escalada = scaler.fit_transform(y_train)

plt.hist(X_train, bins = 100)
plt.show()

plt.hist(X_train_escalada, bins=100)

plt.show()
